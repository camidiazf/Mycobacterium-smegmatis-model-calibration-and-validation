# %% [markdown]
# ## MAIN NOTEBOOK
#
# Main script to run the DAE system simulation and analysis for Mycobacterium smegmatis model calibration and validation.
#
# This script sets up the system parameters, initial conditions, and experimental data for the specified condition,and then runs the simulation and analysis functions.

# %% [markdown]
# # Libraries

# %%
import os
from RUN_functions import RUN_MAIN

# %% [markdown]
# # Parameter Calibration

# %%
folder = 'Excel_Results'
file_name = 'YX_C pH_UL YX_N Xmax.xlsx'  # Specify the path to the Excel file
path = os.path.join(os.getcwd(), folder, 
                    file_name)
perturbation = 0.10
correlation_threshold = 0.95
delta = 1e-4

# %%
# params_list = ['YX_C', 'pH_UL', 'YX_N', 'Xmax', "mu_max"]  # Nombres de los parámetros a ajustar
# lb = [0.2, 6, 5, 0.8, 0.01]     # límites inferiores
# ub = [0.7, 8, 8, 1.2, 0.5]     # límites superior
# n = 5        # Number of iterations

params_list = ['pH_UL']  # Nombres de los parámetros a ajustar
lb = [2]     # límites inferiores
ub = [4]     # límites superior
n = 2     # Number of iterations

Results = RUN_MAIN(iterations = n, 
                    path = path, 
                    perturbation = perturbation, 
                    delta = delta, 
                    correlation_threshold = correlation_threshold, 
                    params_list = params_list, 
                    lb = lb, 
                    ub = ub)
# Out:
# >>> Existing file 'c:\\Users\\camil\\OneDrive\\2025-1\\Ipre_Biosistemas\\DAE_System_Model_Calibration_and_Validation\\Excel_Results\\YX_C pH_UL YX_N Xmax.xlsx' removed | starting fresh
# >>> Starting with empty DataFrame
# >>> Written new file 'c:\\Users\\camil\\OneDrive\\2025-1\\Ipre_Biosistemas\\DAE_System_Model_Calibration_and_Validation\\Excel_Results\\YX_C pH_UL YX_N Xmax.xlsx'
#
#
#                                  ...... Running iteration 1 of 2 ......
#
#
# --------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------- ORIGINAL MODEL -----------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
#
#
#                               --------------- Validation - Residual Analysis ---------------
#
# Validation Results:
# AIC:  [-109.51579257]
#
# Anderson-Darling test statistic: 1.4169016333623716
# Critical values and significance levels:
#   Significance level 15.0%: Critical value 0.528
#   Significance level 10.0%: Critical value 0.601
#   Significance level 5.0%: Critical value 0.721
#   Significance level 2.5%: Critical value 0.841
#   Significance level 1.0%: Critical value 1.0
#
# Durbin-Watson statistic: 0.9175704282545138
# CasADi - 2025-07-10 02:19:31 WARNING("The options 't0', 'tf', 'grid' and 'output_t0' have been deprecated.
# The same functionality is provided by providing additional input arguments to the 'integrator' function, in particular:
#  * Call integrator(..., t0, tf, options) for a single output time, or
#  * Call integrator(..., t0, grid, options) for multiple grid points.
# The legacy 'output_t0' option can be emulated by including or excluding 't0' in 'grid'.
# Backwards compatibility is provided in this release only.") [D:\bld\casadi_1739119754930\work\casadi\core\integrator.cpp:521]
#
# --------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------ MODEL COMPARISON TO VALIDATION DATA -------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
#
#                                   ----------------- Parameter Analysis -----------------
#
#                                         >>>>>>>>>> Sensitivity Analysis <<<<<<<<<<
#
#                                             >>>>>>>>>> FIM Analysis <<<<<<<<<<
#
# FIM condition number: 2.75e+19
# FIM rank: 11
# FIM eigenvalues: [3.82434159e-06 1.62938296e-03 2.82669313e-03 4.36027743e-01
#  4.76655032e+02 1.29921649e+03 1.59050674e+04 2.86996481e+04
#  2.05101917e+05 4.25189541e+06 8.83144857e+06 6.16440371e+07
#  4.02853349e+10 1.07333767e+13]
# 2025/07/10 02:19:35 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: OriginalPSO(epoch=100, pop_size=50, c1=1.5, c2=1.5, w=0.5)
# Highly correlated parameter pairs (|ρ| > 0.95):
#
# k_C        <--> k_N        | correlation: -0.9969
# k_C        <--> YX_O2      | correlation: -0.9620
# k_C        <--> mu_max     | correlation: -0.9955
# k_C        <--> pH_UL      | correlation: -0.9889
# k_N        <--> YX_O2      | correlation: 0.9681
# k_N        <--> mu_max     | correlation: 0.9996
# k_N        <--> pH_LL      | correlation: -0.9587
# k_N        <--> pH_UL      | correlation: 0.9949
# k_N        <--> I_val      | correlation: 0.9590
# k_O        <--> YX_O2      | correlation: 0.9929
# k_O        <--> pH_LL      | correlation: -0.9934
# k_O        <--> pH_UL      | correlation: 0.9689
# k_O        <--> I_val      | correlation: 0.9933
# YX_O2      <--> mu_max     | correlation: 0.9742
# YX_O2      <--> pH_LL      | correlation: -0.9902
# YX_O2      <--> pH_UL      | correlation: 0.9875
# YX_O2      <--> I_val      | correlation: 0.9902
# mu_max     <--> pH_LL      | correlation: -0.9659
# mu_max     <--> pH_UL      | correlation: 0.9973
# mu_max     <--> I_val      | correlation: 0.9662
# pH_LL      <--> pH_UL      | correlation: -0.9811
# pH_LL      <--> I_val      | correlation: -1.0000
# pH_UL      <--> I_val      | correlation: 0.9813
#
# Appended row, df rows went 0 → 1
# Saved to c:\Users\camil\OneDrive\2025-1\Ipre_Biosistemas\DAE_System_Model_Calibration_and_Validation\Excel_Results\YX_C pH_UL YX_N Xmax.xlsx
#
#
#                                  ...... Running iteration 2 of 2 ......
#
#
# --------------------------------------------------------------------------------------------------------------------------
# ------------------------ PSO OPTIMIZATION FOR PARAMETER CALIBRATION | Iteration 2 -------------------------
# --------------------------------------------------------------------------------------------------------------------------
#
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_REP_RES_ERR". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_REP_RES_ERR". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_REP_RES_ERR". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0, repeated recoverable residual errors.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0, repeated recoverable residual errors.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 3.0478e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 3.0478e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0, repeated recoverable residual errors.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# CasADi - 2025-07-10 02:19:35 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# 2025/07/10 02:19:35 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 1, Current best: 12343.495342135371, Global best: 12343.495342135371, Runtime: 0.32341 seconds
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# ...
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# 2025/07/10 02:20:08 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 60, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.55882 seconds
# 2025/07/10 02:20:08 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 61, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.54807 seconds
# 2025/07/10 02:20:09 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 62, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.49001 seconds
# 2025/07/10 02:20:09 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 63, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.50597 seconds
# 2025/07/10 02:20:10 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 64, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.55470 seconds
# 2025/07/10 02:20:11 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 65, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.55117 seconds
# 2025/07/10 02:20:11 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 66, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53876 seconds
# 2025/07/10 02:20:12 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 67, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.48928 seconds
# 2025/07/10 02:20:12 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 68, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.48327 seconds
# 2025/07/10 02:20:13 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 69, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.54571 seconds
# 2025/07/10 02:20:13 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 70, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53304 seconds
# 2025/07/10 02:20:14 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 71, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.48534 seconds
# 2025/07/10 02:20:14 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 72, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.49124 seconds
# 2025/07/10 02:20:15 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 73, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.62638 seconds
# 2025/07/10 02:20:15 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 74, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.55284 seconds
# 2025/07/10 02:20:16 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 75, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.50038 seconds
# CasADi - 2025-07-10 02:20:16 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:20:16 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# 2025/07/10 02:20:16 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 76, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.54078 seconds
# CasADi - 2025-07-10 02:20:16 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:20:16 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 3.0478e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# 2025/07/10 02:20:17 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 77, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.58207 seconds
# 2025/07/10 02:20:17 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 78, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53472 seconds
# 2025/07/10 02:20:18 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 79, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.66846 seconds
# 2025/07/10 02:20:19 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 80, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.54068 seconds
# 2025/07/10 02:20:19 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 81, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.47670 seconds
# 2025/07/10 02:20:20 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 82, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.47167 seconds
# 2025/07/10 02:20:20 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 83, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.51495 seconds
# 2025/07/10 02:20:21 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 84, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.51350 seconds
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# 2025/07/10 02:20:21 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 85, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.59992 seconds
# 2025/07/10 02:20:22 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 86, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53872 seconds
# 2025/07/10 02:20:22 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 87, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.48393 seconds
# 2025/07/10 02:20:23 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 88, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.51347 seconds
# CasADi - 2025-07-10 02:20:23 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# 2025/07/10 02:20:23 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 89, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.65838 seconds
# 2025/07/10 02:20:24 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 90, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.60160 seconds
# 2025/07/10 02:20:25 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 91, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.56485 seconds
# 2025/07/10 02:20:25 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 92, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53955 seconds
# 2025/07/10 02:20:26 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 93, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.54846 seconds
# 2025/07/10 02:20:26 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 94, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.49147 seconds
# 2025/07/10 02:20:27 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 95, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53912 seconds
# CasADi - 2025-07-10 02:20:27 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# CasADi - 2025-07-10 02:20:27 WARNING("integrator:daeF failed: Inf detected for output ode, at (row 0, col 0).") [D:\bld\casadi_1739119754930\work\casadi\core\oracle_function.cpp:393]
# At t = 0, repeated recoverable residual errors.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_REP_RES_ERR". Consult IDAS documentation.
# 2025/07/10 02:20:27 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 96, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.49747 seconds
# 2025/07/10 02:20:28 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 97, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.53776 seconds
# 2025/07/10 02:20:28 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 98, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.50544 seconds
# 2025/07/10 02:20:29 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 99, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.49850 seconds
# At t = 0 and h = 1.21912e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# 2025/07/10 02:20:29 AM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 100, Current best: 12342.384033315358, Global best: 12342.384033315358, Runtime: 0.55397 seconds
# Optimization Results:
#      Best Solutions:  [2.06761276]
#      Minimum Error: 12342.384033315358
#      Optimization Time: 54.70 s
#
# --------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------- NEW PARAMETERS MODEL 2 -------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
#
# Parameter 'pH_UL' is between the limits (2, 4).
#   Parameter  Original       New
# 0     pH_UL       7.4  2.067613
#
#                               --------------- Validation - Residual Analysis ---------------
#
# Validation Results:
# AIC:  [211.44118001]
#
# Anderson-Darling test statistic: 3.2487209787640055
# Critical values and significance levels:
#   Significance level 15.0%: Critical value 0.528
#   Significance level 10.0%: Critical value 0.601
#   Significance level 5.0%: Critical value 0.721
#   Significance level 2.5%: Critical value 0.841
#   Significance level 1.0%: Critical value 1.0
#
# Durbin-Watson statistic: 0.31923831107724515
#
# --------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------ MODEL COMPARISON TO VALIDATION DATA -------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
#
#                                   ----------------- Parameter Analysis -----------------
#
#                                         >>>>>>>>>> Sensitivity Analysis <<<<<<<<<<
# At t = 0 and h = 9.53674e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# Integration was not performed: Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:1432:
# Error in Function::call for 'integrator' [IdasInterface] at D:\bld\casadi_1739119754930\work\casadi\core\function.cpp:361:
# D:\bld\casadi_1739119754930\work\casadi\interfaces\sundials\idas_interface.cpp:596: IDASolve returned "IDA_CONV_FAIL". Consult IDAS documentation.
# !!!!!!!!!!!!!               Simulation with parameter pH_LL perturbed down failed. Please check the parameters and initial conditions.
# !!!!!!!!!!!!!               Validation Analysis for parameter pH_LL failed. Please check the parameters and initial conditions.
#
#                                             >>>>>>>>>> FIM Analysis <<<<<<<<<<
#
# FIM condition number: 4.42e+14
# FIM rank: 13
# FIM eigenvalues: [1.13551434e+02 4.74481807e+02 1.22875149e+03 3.29702648e+03
#  3.87047843e+03 9.63784958e+03 1.63709602e+04 2.21313606e+04
#  4.40802178e+04 6.06894724e+05 1.88416452e+08 1.83103292e+09
#  2.26490616e+11 5.01935554e+16]
# Highly correlated parameter pairs (|ρ| > 0.95):
#
# YX_O2      <--> O2_sat     | correlation: -1.0000
#
#                                               >>>>>>>>>> t-values <<<<<<<<<<
#
# pH_UL     : θ = 2.067613, SE = 0.000707, t-value = 2922.91
# Not adding sensitivity data for this iteration, it is None
#
# Appended row, df rows went 1 → 2
# Saved to c:\Users\camil\OneDrive\2025-1\Ipre_Biosistemas\DAE_System_Model_Calibration_and_Validation\Excel_Results\YX_C pH_UL YX_N Xmax.xlsx
#
#
#
#  ALL ITERATIONS DONE — final df shape: (2, 37)
#
# --------------------------------------------------------------------------------------------------------------------------
# ------------------------------- SUMMARY OF ['pH_UL'] CALIBRATION --------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
#
# No sensitivity data available for plotting.
